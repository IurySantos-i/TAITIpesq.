# %%
import json
import requests
import os
import pandas as pd
import re
from datetime import datetime

def atoi(text):
    return int(text) if text.isdigit() else text

def natural_keys(text):
    '''
    alist.sort(key=natural_keys) sorts in human order
    http://nedbatchelder.com/blog/200712/human_sorting.html
    (See Toothy's implementation in the comments)
    '''
    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

def Union(lst1, lst2):
    final_list = list(set(lst1) | set(lst2))
    return final_list

def Matchmaker(lsttuple, lst):
    final = []
    for str in lst:
        for tuple in lsttuple:
         if str == tuple[0]:
            final.append(tuple[1])
    return list(dict.fromkeys(final))

def intersection(lst1, lst2):
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

def get_commit_date(commit_hash):
    
    # Get commit details from GitHub API
    url = f'https://api.github.com/repos/{donoDoRepositorio}/{repositorio}/commits/{commit_hash}'
    response = requests.get(url)
    data = json.loads(response.text)
    print(data)
    commit_data = data['commit']["author"]["date"]
    print(commit_data)
    
    # Convert commit date string to datetime object
    commit_date = datetime.strptime(commit_data, '%Y-%m-%dT%H:%M:%SZ')
    return commit_date

def calculate_days_between_commits(commit_hash1, commit_hash2):
    commit_date1 = get_commit_date(commit_hash1) # Mais antigo
    commit_date2 = get_commit_date(commit_hash2) # Mais Recente
    
    # Calculate timedelta between commit dates
    delta = commit_date2 - commit_date1
    return delta.days


arquivoTaiti = 'https___github.com_EFForg_action-center-platform.csv'
partes = arquivoTaiti.split("_")
donoDoRepositorio = partes[-2]
repositorio = partes[-1].split(".")[0]

tasksDoProjeto = pd.read_excel('formalized_tasks_action-center-platform.git.xlsx')
ultimosCommits = tasksDoProjeto[['Oldest Commit','Most Recent Commit']]

print(calculate_days_between_commits((ultimosCommits.loc[1][0]), ultimosCommits.loc[1][1]))
# Out:
# /tmp/ipykernel_6556/282668118.py:66: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(calculate_days_between_commits((ultimosCommits.loc[1][0]), ultimosCommits.loc[1][1]))
# {'sha': '0806fb92eb2178a31dec72df57b4d75979fbfe17', 'node_id': 'MDY6Q29tbWl0MzY1MzQzNTM6MDgwNmZiOTJlYjIxNzhhMzFkZWM3MmRmNTdiNGQ3NTk3OWZiZmUxNw==', 'commit': {'author': {'name': 'Peter Woo', 'email': 'peter@wioux.net', 'date': '2016-10-19T18:32:08Z'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'date': '2016-10-19T18:32:08Z'}, 'message': 'Merge pull request #231 from EFForg/fix_partner_link\n\nFix partner link', 'tree': {'sha': '334a18659867fe27aeda6bbae317b496aa67d4ad', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/git/trees/334a18659867fe27aeda6bbae317b496aa67d4ad'}, 'url': 'https://api.github.com/repos/EFForg/action-center-platform/git/commits/0806fb92eb2178a31dec72df57b4d75979fbfe17', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}, 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/0806fb92eb2178a31dec72df57b4d75979fbfe17', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/0806fb92eb2178a31dec72df57b4d75979fbfe17', 'comments_url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/0806fb92eb2178a31dec72df57b4d75979fbfe17/comments', 'author': {'login': 'wioux', 'id': 6469642, 'node_id': 'MDQ6VXNlcjY0Njk2NDI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6469642?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/wioux', 'html_url': 'https://github.com/wioux', 'followers_url': 'https://api.github.com/users/wioux/followers', 'following_url': 'https://api.github.com/users/wioux/following{/other_user}', 'gists_url': 'https://api.github.com/users/wioux/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/wioux/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/wioux/subscriptions', 'organizations_url': 'https://api.github.com/users/wioux/orgs', 'repos_url': 'https://api.github.com/users/wioux/repos', 'events_url': 'https://api.github.com/users/wioux/events{/privacy}', 'received_events_url': 'https://api.github.com/users/wioux/received_events', 'type': 'User', 'site_admin': False}, 'committer': {'login': 'web-flow', 'id': 19864447, 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3', 'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/web-flow', 'html_url': 'https://github.com/web-flow', 'followers_url': 'https://api.github.com/users/web-flow/followers', 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}', 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions', 'organizations_url': 'https://api.github.com/users/web-flow/orgs', 'repos_url': 'https://api.github.com/users/web-flow/repos', 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}', 'received_events_url': 'https://api.github.com/users/web-flow/received_events', 'type': 'User', 'site_admin': False}, 'parents': [{'sha': '59100938172b11a257ec9beaf66612423f210213', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/59100938172b11a257ec9beaf66612423f210213', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/59100938172b11a257ec9beaf66612423f210213'}, {'sha': 'bb21bd1d2840b904a51ae080ec7e713cc6030aa8', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/bb21bd1d2840b904a51ae080ec7e713cc6030aa8', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/bb21bd1d2840b904a51ae080ec7e713cc6030aa8'}], 'stats': {'total': 94, 'additions': 4, 'deletions': 90}, 'files': [{'sha': '4266908d52975df3a8ffc6ee13b5a756336c0ac2', 'filename': 'app/views/admin/partners/edit.html.erb', 'status': 'removed', 'additions': 0, 'deletions': 6, 'changes': 6, 'blob_url': 'https://github.com/EFForg/action-center-platform/blob/59100938172b11a257ec9b ...
# 2016-10-19T18:32:08Z
# {'sha': '076e3558eaa6a07c95f167487365d09eeb60af3b', 'node_id': 'MDY6Q29tbWl0MzY1MzQzNTM6MDc2ZTM1NThlYWE2YTA3Yzk1ZjE2NzQ4NzM2NWQwOWVlYjYwYWYzYg==', 'commit': {'author': {'name': 'Peter Woo', 'email': 'peter@wioux.net', 'date': '2016-10-25T18:07:37Z'}, 'committer': {'name': 'GitHub', 'email': 'noreply@github.com', 'date': '2016-10-25T18:07:37Z'}, 'message': 'Merge pull request #235 from EFForg/register_workflow\n\nBetter privacy for user registration', 'tree': {'sha': '646ff4d4f59ceb72053241097e2a3ef95c050a36', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/git/trees/646ff4d4f59ceb72053241097e2a3ef95c050a36'}, 'url': 'https://api.github.com/repos/EFForg/action-center-platform/git/commits/076e3558eaa6a07c95f167487365d09eeb60af3b', 'comment_count': 0, 'verification': {'verified': False, 'reason': 'unsigned', 'signature': None, 'payload': None}}, 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/076e3558eaa6a07c95f167487365d09eeb60af3b', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/076e3558eaa6a07c95f167487365d09eeb60af3b', 'comments_url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/076e3558eaa6a07c95f167487365d09eeb60af3b/comments', 'author': {'login': 'wioux', 'id': 6469642, 'node_id': 'MDQ6VXNlcjY0Njk2NDI=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6469642?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/wioux', 'html_url': 'https://github.com/wioux', 'followers_url': 'https://api.github.com/users/wioux/followers', 'following_url': 'https://api.github.com/users/wioux/following{/other_user}', 'gists_url': 'https://api.github.com/users/wioux/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/wioux/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/wioux/subscriptions', 'organizations_url': 'https://api.github.com/users/wioux/orgs', 'repos_url': 'https://api.github.com/users/wioux/repos', 'events_url': 'https://api.github.com/users/wioux/events{/privacy}', 'received_events_url': 'https://api.github.com/users/wioux/received_events', 'type': 'User', 'site_admin': False}, 'committer': {'login': 'web-flow', 'id': 19864447, 'node_id': 'MDQ6VXNlcjE5ODY0NDQ3', 'avatar_url': 'https://avatars.githubusercontent.com/u/19864447?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/web-flow', 'html_url': 'https://github.com/web-flow', 'followers_url': 'https://api.github.com/users/web-flow/followers', 'following_url': 'https://api.github.com/users/web-flow/following{/other_user}', 'gists_url': 'https://api.github.com/users/web-flow/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/web-flow/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/web-flow/subscriptions', 'organizations_url': 'https://api.github.com/users/web-flow/orgs', 'repos_url': 'https://api.github.com/users/web-flow/repos', 'events_url': 'https://api.github.com/users/web-flow/events{/privacy}', 'received_events_url': 'https://api.github.com/users/web-flow/received_events', 'type': 'User', 'site_admin': False}, 'parents': [{'sha': '73d02fa93957a47c9a63aa2dcfd37b38489a93dc', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/73d02fa93957a47c9a63aa2dcfd37b38489a93dc', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/73d02fa93957a47c9a63aa2dcfd37b38489a93dc'}, {'sha': 'fa010b744b6fc2e5d6a0c97e23359507c083c54b', 'url': 'https://api.github.com/repos/EFForg/action-center-platform/commits/fa010b744b6fc2e5d6a0c97e23359507c083c54b', 'html_url': 'https://github.com/EFForg/action-center-platform/commit/fa010b744b6fc2e5d6a0c97e23359507c083c54b'}], 'stats': {'total': 207, 'additions': 194, 'deletions': 13}, 'files': [{'sha': 'b1dc1cd888c519a4a2026a9997478d3e639510c7', 'filename': 'app/controllers/registrations_controller.rb', 'status': 'modified', 'additions': 42, 'deletions': 2, 'changes': 44, 'blob_url': 'https://github.com/EFForg/action-center-plat ...
# 2016-10-25T18:07:37Z
# 5
